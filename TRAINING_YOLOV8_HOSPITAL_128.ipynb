# %%
# Dependencies
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.9/626.9 kB 19.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Data Importing (Google drive + Google Colab)

# %%
# Only Colab's
from google.colab import drive
G_DRIVE_MOUNTPOINT = "/drive"
drive.mount(G_DRIVE_MOUNTPOINT)
# !unzip '/drive/MyDrive/Colab Notebooks/yolo_oid_data/hospital/hospital4.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: hospital/images/train/ambulance_08c9112d1f718cdb.jpg
#   inflating: hospital/images/train/wheelchair_406bb156fc7f7f53.jpg
#   inflating: hospital/images/train/bed_03e4dd0a6c7a8da0.jpg
#   inflating: hospital/images/train/wheelchair_26407a63bae2a34a.jpg
#   inflating: hospital/images/train/stethoscope_dd75e96c2e8cd1d8.jpg
#   inflating: hospital/images/train/ambulance_31b1c599fd0f2280.jpg
#   inflating: hospital/images/train/ambulance_5e61a07f1d23ec8d.jpg
#   inflating: hospital/images/train/medical_equipment_0db4ac0c8016415f.jpg
#   inflating: hospital/images/train/wheelchair_420975c9670fd6bc.jpg
#   inflating: hospital/images/train/human_face_002250249e2eaa0a.jpg
#   inflating: hospital/images/train/medical_equipment_48de43b8fca5f8f3.jpg
#   inflating: hospital/images/train/human_face_0014ca12f4d5c614.jpg
#   inflating: hospital/images/train/human_face_000c0d0c3585e157.jpg
# ...

# %% [markdown]
# #Model Training

# %%
import os
import sys


# main code to run YOLO training
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")     # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/hospital/data.yaml", epochs=128, pretrained=True, iou=0.1, visualize=True, patience=0)  # train the model
results = model.val()  # evaluate model performance on the validation set
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 208MB/s]
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Model Downloading

# %%
import shutil
from google.colab import files


# Create a zip file
shutil.make_archive("/content/file_128FACE", 'zip', "/content/runs")
files.download("/content/file_128FACE" + '.zip')
